# %% [markdown]
# <a href="https://colab.research.google.com/github/takaito1/EAS4821_S2024/blob/main/templates/ItoT_QM_Lab1template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quantitative techniques lab report template
#
# #### **Author**: Taka Ito
# #### **Email**: taka.ito@eas.gatech.edu
#
# #### **Introduction**
# In this lab report, we describe the tools for fundamental data processing and presentation including numpy and matplotlib packages. Numpy is a python library that ...
# The overall structure of this report is as follows.
# 1. Loading numpy and matplotlib packages
# 2. Introduction to numpy
# 3. Introduction to matplotlib
# 4. Discussion

# %% [markdown]
# ## 1. Loading packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Introduction to Numpy

# %%
# np.genfromtxt() reads text data
data = np.genfromtxt('/content/drive/MyDrive/EAS2655_4821/atlanta.csv',delimiter=',',skip_header=2)

# %%
# .dtype tells you what data type it is in
data.dtype
# Out:
# dtype('float64')

# %%
# .shape tells you the dimension of numpy array
data.shape
# Out:
# (144, 14)

# %%
# get year from the first column
year = data[:,0]
# get July data from the 8th column (index = 7)
Jul = data[:,7]

# %%
# simply display the data
print('year is ',year)
print('July temperature is ',Jul)
# Out:
# year is  [1880. 1881. 1882. 1883. 1884. 1885. 1886. 1887. 1888. 1889. 1890. 1891.
#  1892. 1893. 1894. 1895. 1896. 1897. 1898. 1899. 1900. 1901. 1902. 1903.
#  1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911. 1912. 1913. 1914. 1915.
#  1916. 1917. 1918. 1919. 1920. 1921. 1922. 1923. 1924. 1925. 1926. 1927.
#  1928. 1929. 1930. 1931. 1932. 1933. 1934. 1935. 1936. 1937. 1938. 1939.
#  1940. 1941. 1942. 1943. 1944. 1945. 1946. 1947. 1948. 1949. 1950. 1951.
#  1952. 1953. 1954. 1955. 1956. 1957. 1958. 1959. 1960. 1961. 1962. 1963.
#  1964. 1965. 1966. 1967. 1968. 1969. 1970. 1971. 1972. 1973. 1974. 1975.
#  1976. 1977. 1978. 1979. 1980. 1981. 1982. 1983. 1984. 1985. 1986. 1987.
#  1988. 1989. 1990. 1991. 1992. 1993. 1994. 1995. 1996. 1997. 1998. 1999.
#  2000. 2001. 2002. 2003. 2004. 2005. 2006. 2007. 2008. 2009. 2010. 2011.
#  2012. 2013. 2014. 2015. 2016. 2017. 2018. 2019. 2020. 2021. 2022. 2023.]
# ...

# %% [markdown]
# ## 3. Introduction to matplotlib

# %%
# generate a time series plot
plt.plot(year,Jul)
# add x label
plt.xlabel('time')
# add y label
plt.ylabel('monthly mean July temperature, deg F')
# add title
plt.title('monthly mean temperature of Atlanta GA')
# if preferred, you can generate a graphic file
plt.savefig('Figure1-1.pdf',bbox_inches='tight')
plt.show()

# %%
# Generate a histogram of July temperature
plt.hist(Jul)
# add x label
plt.xlabel('monthly mean July temperature, deg F')
# add y label
plt.ylabel('frequency')
# add title
plt.title('monthly mean temperature of Atlanta GA')
# if preferred, you can generate a graphic file
plt.savefig('Figure1-2.pdf',bbox_inches='tight')
plt.show()

# %%
# Overlay Gaussian function

# %%
# Box plot
plt.boxplot(Jul)
# add y label
plt.ylabel('monthly mean July temperature, deg F')
# add title
plt.title('monthly mean temperature of Atlanta GA')
# if preferred, you can generate a graphic file
plt.savefig('Figure1-3.pdf',bbox_inches='tight')
plt.show()

# %%
# plot box diagram together for all months

# %% [markdown]
# ## 4. Discussion
# Conclude the lab report with a brief discussion including what you did, what new information you have learned, and your interpretation of the results. In this sample report, we practiced creating a report using JupyterLab. We utilized simple functions in numpy (array calculations) and matplotlib (2D plot) using Atlanta's monthly mean temperature as an example.
